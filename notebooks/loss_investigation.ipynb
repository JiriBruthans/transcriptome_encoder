# %%
### the loss doesn't seem to converg to 0, even when overfitting for 500 steps with AdamW 3e-4. Is it because of random gene selection?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

with open('losses.txt', 'r') as f:
    lines = f.readlines()

steps = []
losses = []
for line in lines:
    # Format: "loss: 0.7042100429534912 for step 0"
    parts = line.split()
    steps.append(int(parts[-1]))
    losses.append(float(parts[1]))

df = pd.DataFrame({'step': steps, 'loss': losses})

plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['loss'], marker='o')
plt.title('Training Loss Over Time')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

with open('losses.txt', 'r') as f:
    lines = f.readlines()

steps = []
losses = []
for line in lines:
    parts = line.split()
    steps.append(int(parts[-1]))
    losses.append(float(parts[1]))

df = pd.DataFrame({'step': steps, 'loss': losses})
df['log_step'] = np.log(df['step'] + 1)  # Add 1 to handle step 0

plt.figure(figsize=(10, 6))
plt.plot(df['log_step'], df['loss'], marker='o')
plt.title('Training Loss vs Log Steps')
plt.xlabel('Log Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
#one epoch on human tongue

df = pd.read_csv('../logs/loss_log.csv', header=None)
df.columns = ['step', 'loss']

df['log_step'] = np.log(df['step'] + 1)  # Add 1 to handle step 0

plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['loss'], marker='o')
plt.title('Training Loss vs Steps')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(df['log_step'], df['loss'], marker='o')
plt.title('Training Loss vs Log Steps')
plt.xlabel('Log Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
#one epoch on human tongue

df = pd.read_csv('../logs/loss_log_10_epoch.csv', header=None)
df.columns = ['epoch', 'step', 'loss', 'cells_per_second']

df['log_step'] = np.log(df['step'] + 1)  # Add 1 to handle step 0

plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['loss'], marker='o')
plt.title('Training Loss vs Steps')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(df['log_step'], df['loss'], marker='o')
plt.title('Training Loss vs Log Steps')
plt.xlabel('Log Step')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# steps vs cells per second
plt.figure(figsize=(10, 6))
plt.plot(df['step'], df['cells_per_second'], marker='o')
plt.title('Cells per second vs Steps')
plt.xlabel('Step')
plt.ylabel('Cells per second')
plt.grid(True)
plt.show()
